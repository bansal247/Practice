# %% [markdown]
# # SQL

# %%
from platform import python_version

print(python_version())
# Out:
# 3.9.7

# %%
import mysql.connector as connection

# %%
try:
    mydb = connection.connect(host="localhost",user="root",passwd="Shashu@247",use_pure=True) #use_pure to use pure python
                                                                                              #implementation not C 
                                                                                              #implemtation
    query = "SHOW DATABASES"
    
    cursor = mydb.cursor()
    cursor.execute(query)
    print(cursor.fetchall())
    
except Exception as e:
    mydb.close()
    print(str(e))
else:
    mydb.close()
# Out:
# [('information_schema',), ('mysql',), ('performance_schema',), ('sakila',), ('sys',), ('world',)]

# %%
conn = connection.connect(host="localhost",user="root",passwd="Shashu@247",use_pure=True)

# %%
cur = conn.cursor()

# %%
type(cur.execute("show databases"))
# Out:
# NoneType

# %%
next(cur)
# Out:
# ('information_schema',)

# %%
cur.fetchall()
# Out:
# [('mysql',), ('performance_schema',), ('sakila',), ('sys',), ('world',)]

# %%
conn.close()

# %%
try:
    mydb = connection.connect(host="localhost",user="root",passwd="Shashu@247",use_pure=True) #use_pure to use pure python
                                                                                              #implementation not C 
                                                                                              #implemtation
    query = "drop database test1234"
    
    cursor = mydb.cursor()
    cursor.execute(query)
    print(cursor.fetchall())
    
except Exception as e:
    mydb.close()
    print(str(e))
else:
    mydb.close()
# Out:
# []

# %%
try:
    mydb = connection.connect(host="localhost",user="root",passwd="Shashu@247",use_pure=True) #use_pure to use pure python
                                                                                              #implementation not C 
    cursor = mydb.cursor()                                                                                         #implemtation
    query = "create database if not exists student1"
    cursor.execute(query)
    cursor.execute("use student1")
    cursor.execute("create table if not exists student_details (id int)")
    cursor.execute("explain student_details")
    print(cursor.fetchall())
    
except Exception as e:
    mydb.rollback()
    mydb.close()
    print(str(e))
else:
    mydb.commit()
    mydb.close()
# Out:
# [('id', b'int', 'YES', '', None, '')]

# %%
mydb = connection.connect(host="localhost",user="root",passwd="Shashu@247",database = "student1",use_pure=True) #use_pure to use pure python
                                                                                              #implementation not C 
cursor = mydb.cursor()                                                                                         #implemtation
query1 = "create table if not exists student_details1 (id int,name varchar(20))"
query2 = "insert into student_details1 values(1,'shashwat')"

cursor.execute(query1)

# %%
query1 = "create table if not exists student_details3 (id int,name varchar(20))"

cursor.execute(query1)

# %%
cursor.execute(query2)

# %%
cursor.execute("select * from student_details1")

# %%
cursor.fetchall()
# Out:
# [(1, 'shashwat')]

# %%
mydb.commit()

# %%
values = [(2,'bansal'),(3,'svsvds'),(4,'sdvdsve'),(5,'sdvsrgwrgew')]

# %%
cursor.executemany('insert into student_details1(id,name) values("%s","%s")',values)

# %%
cursor.fetchall()
# Out:
# [(1, 'shashwat'),
#  (2, "'bansal'"),
#  (3, "'svsvds'"),
#  (4, "'sdvdsve'"),
#  (5, "'sdvsrgwrgew'")]

# %%
cursor.executemany('insert into student_details1(id,name) values("%s","%s")',values)

# %%
cursor.fetchall()
# Out:
# [(1, 'shashwat'),
#  (2, "'bansal'"),
#  (3, "'svsvds'"),
#  (4, "'sdvdsve'"),
#  (5, "'sdvsrgwrgew'")]

# %%
mydb.rollback()

# %%
import pandas as pd

# %%
mydb

# %%
a = pd.read_sql("select * from student_details1",mydb)

# %%
a.to_csv('mydata.csv')

# %%
cur = mydb.cursor()

# %%
cur.execute("create table if not exists mydata(id_new int,name_new varchar(20))")

# %%
data = pd.read_csv('mydata.csv')

# %%
data.iloc[:,1:]
# Out:
#    id           name
# 0   1       shashwat
# 1   2       'bansal'
# 2   3       'svsvds'
# 3   4      'sdvdsve'
# 4   5  'sdvsrgwrgew'

# %%
r = open('mydata.csv')

# %%
k = r.read()

# %%
import csv

# %%
data2 = csv.reader(k)

# %%
import os

# %%
os.chdir('C:\\Users\\Shashwat\\Desktop\\Ineuron\\Files\\19.2.MySQL')

# %%
cur.execute("CREATE TABLE IF NOT EXISTS GlassData (Index_Number INT(10),RI float(10,5), Na float(10,5), Mg float(10,5),Al float(10,5)," \
            " Si float(10,5), K float(10,5), Ca float(10,5), Ba float(10,5), Fe float(10,5), Class INT(5))")

# %%
with open('glass.data','r') as data:
    for i,j in enumerate(data.readlines()):
        if i==0:
            continue
        try:
            cur.execute('insert into GlassData values ({})'.format(j))
        except Exception as e:
            print(e)

# %%
cur.execute('select * from GlassData')
cur.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
with open('glass.data','r') as data:
    next(data)
    data_csv = csv.reader(data,delimiter='\n')
    for i,j in enumerate(data_csv):
        for d in j:
            cur.execute('insert into GlassData values ({})'.format(d))

# %%
mydb.commit()

# %%
set_1 = set({})
with open('carbon_nanotubes.csv') as data:
    data = data.readlines()[1:]
    mydb = connection.connect(host="localhost",user="root",passwd="Shashu@247",use_pure=True)
    cur = mydb.cursor()
    cur.execute('use student1')
    cur.execute('create table if not exists carbon_nanotubes1(i1 int,i2 int,i3 int,i4 int,i5 int,i6 int,i7 int,i8 int,i9 int,i10 int,i11 int,i12 int,i13 int,i14 int null)')
    for i in data:
        i = i.replace(';',',')
        #print(i)
        try:
            cur.execute('insert into carbon_nanotubes1 values({})'.format(i))
        except:
            cur.execute('insert into carbon_nanotubes1 values({},null)'.format(i))
# Out:
# 7,3,0,235578,0,615865,0,795605,0,232297,0,617997,1
#
# 7,4,0,814287,0,87145,0,900365,0,818891,0,875636,1
#
# 7,5,0,369441,0,098484,0,410843,0,363738,0,087356,0
#
# 7,6,0,916246,0,670038,0,086586,0,922894,0,67216,0
#
# 8,1,0,455262,0,808621,0,908939,0,454786,0,814537,1
#
# 8,3,0,470138,0,137374,0,465226,0,470772,0,130205,0
#
# 8,5,0,274618,0,080939,0,401044,0,271033,0,073983,0
#
# 8,5,0,598246,0,195964,0,84678,0,598876,0,193038,1
#
# 8,6,0,35518,0,079514,0,716736,0,353174,0,073926,1
#
# 9,1,0,872109,0,809986,0,846565,0,876269,0,813518,1
#
# 9,2,0,161014,0,136646,0,54787,0,157959,0,131437,1
#
# 9,4,0,228652,0,643322,0,531706,0,220574,0,639249,1
#
# 9,4,0,3412,0,082742,0,88133,0,340207,0,079638,1
#
# 10,1,0,123524,0,169625,0,523828,0,117626,0,165021,1
#
# 10,2,0,898132,0,591132,0,878398,0,903652,0,593684,1
#
# 10,4,0,8043,0,38889,0,449902,0,806413,0,38741,0
#
# 10,6,0,145436,0,551688,0,782897,0,142679,0,552369,1
#
# 11,2,0,591592,0,90684,0,523221,0,592476,0,912334,1
#
# ...

# %%
set_1
# Out:
# {13, 14}

# %%
mydb.rollback()

# %%
mydb.commit()

# %% [markdown]
# # MONGODB

# %% [markdown]
# ## for cloud
# client = pymongo.MongoClient("mongodb+srv://shashu247:<password>@cluster0.lwuf5.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
# db = client.test

# %%
import pymongo
client_cloud = pymongo.MongoClient("mongodb+srv://shashu247:shashu247@cluster0.lwuf5.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# %%
DEFAULT_CONNECTION_URL = "mongodb://localhost:27017/"
DB_NAME = 'iNeuron'

# %%
client = pymongo.MongoClient(DEFAULT_CONNECTION_URL)

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
database = client[DB_NAME]

# %%
database
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'iNeuron')

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %%
record = {'companyName':'ineuron',
         'product':'Affordable Ai',
         'couserOffered':'Deep learning'}

# %%
collection = database['new_ineuron']

# %%
collection.insert_one(record)

# %%
db = client_cloud['Ineuron']

# %%
coll = db['new_neuron']

# %%
coll.insert_one(record)

# %%
record_2 = {'companyName':'ineuron',
         'product':'Affordable Ai',
         'couserOffered':'Deep learning',
           'name':['one','two'],
           'new':{'name':'heelo',
                 'pass':'1234'}}

# %%
collection.insert_one(record_2)

# %%
coll.insert_one(record_2)

# %%
list_records = [
    {'companyName':'ineuron',
         'product':'Affordable Ai',
         'couserOffered':'Deep learning',
           'name':['one','two'],
           'new':{'name':'heelo',
                 'pass':'1234'}},
    {'companyName':'ineuron',
         'product':'Affordable Ai',
         'couserOffered':'Deep learning'},
    {'companyName':'ineuron',
         'product':'Affordable Ai',
         'couserOffered':'Deep learning'}
]

# %%
rec = collection.insert_many(list_records)

# %%
ids = rec.inserted_ids

# %%
for id_ in ids:
    print(id_)
# Out:
# 61ce02e13be57fd14a5ea521
# 61ce02e13be57fd14a5ea522
# 61ce02e13be57fd14a5ea523

# %%
for i in collection.find():
    print(i)
# Out:
# {'_id': ObjectId('61cdfdac3be57fd14a5ea51c'), 'companyName': 'ineuron', 'product': 'Affordable Ai', 'couserOffered': 'Deep learning'}
# {'_id': ObjectId('61cdfef03be57fd14a5ea51e'), 'companyName': 'ineuron', 'product': 'Affordable Ai', 'couserOffered': 'Deep learning', 'name': ['one', 'two'], 'new': {'name': 'heelo', 'pass': '1234'}}
# {'_id': ObjectId('61cdff3102355d72f144c850'), 'companyName': 'ineuron', 'product': 'Affordable Ai', 'couserOffered': 'Deep learning', 'name': ['one', 'two'], 'new': {'name': 'heelo', 'pass': '1234'}}
# {'_id': ObjectId('61ce014a3be57fd14a5ea51f'), 'companyName': 'ineuron', 'product': 'Affordable Ai', 'couserOffered': 'Deep learning', 'name': ['one', 'two'], 'new': {'name': 'heelo', 'pass': '1234'}}
# {'_id': ObjectId('61ce014a3be57fd14a5ea520'), 'companyName': 'ineuron', 'product': 'Affordable Ai', 'couserOffered': 'Deep learning'}
# ...

# %%
for i in collection.find({'name': ['one', 'two']},{'new','companyName'}):
    print(i)
# Out:
# {'_id': ObjectId('61cdfef03be57fd14a5ea51e'), 'companyName': 'ineuron', 'new': {'name': 'heelo', 'pass': '1234'}}
# {'_id': ObjectId('61cdff3102355d72f144c850'), 'companyName': 'ineuron', 'new': {'name': 'heelo', 'pass': '1234'}}
# {'_id': ObjectId('61ce014a3be57fd14a5ea51f'), 'companyName': 'ineuron', 'new': {'name': 'heelo', 'pass': '1234'}}
# {'_id': ObjectId('61ce02e13be57fd14a5ea521'), 'companyName': 'ineuron', 'new': {'name': 'heelo', 'pass': '1234'}}

# %%
for i in collection.find({'id':{'$gt':'1'}}):
    print(i)

# %%
collection.delete_one({'name': ['one', 'two']})

# %%
for i in collection.find({'name': ['one', 'two']},{'new','companyName'}):
    print(i)
# Out:
# {'_id': ObjectId('61cdff3102355d72f144c850'), 'companyName': 'ineuron', 'new': {'name': 'heelo', 'pass': '1234'}}
# {'_id': ObjectId('61ce014a3be57fd14a5ea51f'), 'companyName': 'ineuron', 'new': {'name': 'heelo', 'pass': '1234'}}
# {'_id': ObjectId('61ce02e13be57fd14a5ea521'), 'companyName': 'ineuron', 'new': {'name': 'heelo', 'pass': '1234'}}

# %%
collection.update_many({'name': ['one', 'two']},{'$set':{'name':{'i1':'i dont know'}}})

# %%
for i in collection.find():
    print(i)
# Out:
# {'_id': ObjectId('61cdfdac3be57fd14a5ea51c'), 'companyName': 'ineuron', 'product': 'Affordable Ai', 'couserOffered': 'Deep learning'}
# {'_id': ObjectId('61cdff3102355d72f144c850'), 'companyName': 'ineuron', 'product': 'Affordable Ai', 'couserOffered': 'Deep learning', 'name': {'i1': 'i dont know'}, 'new': {'name': 'heelo', 'pass': '1234'}}
# {'_id': ObjectId('61ce014a3be57fd14a5ea51f'), 'companyName': 'ineuron', 'product': 'Affordable Ai', 'couserOffered': 'Deep learning', 'name': {'i1': 'i dont know'}, 'new': {'name': 'heelo', 'pass': '1234'}}
# {'_id': ObjectId('61ce014a3be57fd14a5ea520'), 'companyName': 'ineuron', 'product': 'Affordable Ai', 'couserOffered': 'Deep learning'}
# {'_id': ObjectId('61ce02e13be57fd14a5ea521'), 'companyName': 'ineuron', 'product': 'Affordable Ai', 'couserOffered': 'Deep learning', 'name': {'i1': 'i dont know'}, 'new': {'name': 'heelo', 'pass': '1234'}}
# ...

# %% [markdown]
# # CASSANDRA
